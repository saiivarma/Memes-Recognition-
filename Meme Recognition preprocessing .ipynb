# %%
import os
import glob
import numpy as np
import pandas as pd
import keras
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from skimage.io import imread
from scipy import misc

# %%
paths=[]
os.chdir('/Users/vsvsvarma/Desktop/memes')
for file in glob.glob('*.jpg'):
        paths.append(file)
print(paths)
n=len(paths)
# Out:
# ['dank-memes-try-not-to-laugh-impo.jpg', '94444-smallv2-495419.jpg', 'maxresdefault4.jpg', 'l-24609-when-you-keep-tagging-your-friends-in-dank-memes-but-they-dont-like-your-tag-dont-disrespect-me-like-that.jpg', '1517855579_596_valentines-day-2018-memes-collection-new-latest-memes-happy-valentines-day-2018.jpg', 'dank-memes-vine-compilation-2016.jpg', '01-meme.jpg', 'tamil-memes13-324x160.jpg', '1512047023_best-funny-quotes-25-hilarious-dank-memes.jpg', 'l-24602-dank-memes-that-are-guaranteed-to-make-your-day-2.jpg', 'dank-memes-that-are-guaranteed-to-make-your-day-8.jpg', 'bcb.jpg', 'indianmemes19.jpg', '9e97b6e822b91264de22281a5d89904e.jpg', 'dank-memes-that-are-guaranteed-to-make-your-day-22.jpg', '4840765b89df3d0e73ba15d5938ae2612b3f0ff7_hq.jpg', '4c8591cc76dc0adcd34f47ccb63ac561.jpg', '9cf.jpg', '25-Hilarious-Dank-Memes-3-Hilarious-Memes.jpg', 'dank-memes-compilation-v1-meme-m.jpg', 'hqdefault-142.jpg', 'dank_meme__13_by_h20del1r1ous-d9yu1yi.jpg', '12bnes.jpg', 'DS5C_MZWAAMgM9m.
# ...

# %%
img=[]
imgs=[]
j=0
for i in range(0,n):
    img.append(imread(paths[i]))
    imgs.append(misc.imresize(img[i],(600,600)))
    j+=1
# Out:
# /Users/vsvsvarma/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.

# %%
labels=[]
for i in range(n):
    print(i," ",imgs[i].shape)
    labels.append(1)
# Out:
# 0   (600, 600, 3)
# 1   (600, 600, 3)
# 2   (600, 600, 3)
# 3   (600, 600, 3)
# 4   (600, 600, 3)
# 5   (600, 600, 3)
# 6   (600, 600, 3)
# 7   (600, 600, 3)
# 8   (600, 600, 3)
# 9   (600, 600, 3)
# 10   (600, 600, 3)
# 11   (600, 600, 3)
# 12   (600, 600, 3)
# 13   (600, 600, 3)
# 14   (600, 600, 3)
# 15   (600, 600, 3)
# 16   (600, 600, 3)
# 17   (600, 600, 3)
# 18   (600, 600, 3)
# 19   (600, 600, 3)
# 20   (600, 600, 3)
# 21   (600, 600, 3)
# 22   (600, 600, 3)
# 23   (600, 600, 3)
# 24   (600, 600, 3)
# 25   (600, 600, 3)
# 26   (600, 600, 3)
# 27   (600, 600, 3)
# 28   (600, 600, 3)
# 29   (600, 600, 3)
# 30   (600, 600, 3)
# 31   (600, 600, 3)
# 32   (600, 600, 3)
# 33   (600, 600, 3)
# 34   (600, 600, 3)
# 35   (600, 600, 3)
# 36   (600, 600, 3)
# 37   (600, 600, 3)
# 38   (600, 600, 3)
# 39   (600, 600, 3)
# 40   (600, 600, 3)
# 41   (600, 600, 3)
# 42   (600, 600, 3)
# 43   (600, 600, 3)
# 44   (600, 600, 3)
# 45   (600, 600, 3)
# 46   (600, 600, 3)
# 47   (600, 600, 3)
# ...

# %%
imgs.pop(566)
len(imgs)
for i in range(len(imgs)):
    print(i," ",imgs[i].shape," ",labels[i])
# Out:
# 0   (600, 600, 3)   1
# 1   (600, 600, 3)   1
# 2   (600, 600, 3)   1
# 3   (600, 600, 3)   1
# 4   (600, 600, 3)   1
# 5   (600, 600, 3)   1
# 6   (600, 600, 3)   1
# 7   (600, 600, 3)   1
# 8   (600, 600, 3)   1
# 9   (600, 600, 3)   1
# 10   (600, 600, 3)   1
# 11   (600, 600, 3)   1
# 12   (600, 600, 3)   1
# 13   (600, 600, 3)   1
# 14   (600, 600, 3)   1
# 15   (600, 600, 3)   1
# 16   (600, 600, 3)   1
# 17   (600, 600, 3)   1
# 18   (600, 600, 3)   1
# 19   (600, 600, 3)   1
# 20   (600, 600, 3)   1
# 21   (600, 600, 3)   1
# 22   (600, 600, 3)   1
# 23   (600, 600, 3)   1
# 24   (600, 600, 3)   1
# 25   (600, 600, 3)   1
# 26   (600, 600, 3)   1
# 27   (600, 600, 3)   1
# 28   (600, 600, 3)   1
# 29   (600, 600, 3)   1
# 30   (600, 600, 3)   1
# 31   (600, 600, 3)   1
# 32   (600, 600, 3)   1
# 33   (600, 600, 3)   1
# 34   (600, 600, 3)   1
# 35   (600, 600, 3)   1
# 36   (600, 600, 3)   1
# 37   (600, 600, 3)   1
# 38   (600, 600, 3)   1
# 39   (600, 600, 3)   1
# ...

# %%
image_arr=np.array(imgs)
len(image_arr)
# Out:
# 704

# %%
image_arr.shape
# Out:
# (704, 600, 600, 3)

# %%
plt.imshow(image_arr[500])

# %%
np.random.shuffle(image_arr)

# %%
plt.imshow(image_arr[500])

# %%
x=list(zip(image_arr,labels))

# %%
image_arrs,label=zip(*x)

# %%
plt.imshow(image_arrs[500])
